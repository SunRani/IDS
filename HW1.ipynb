# %% [markdown]
# <a href="https://colab.research.google.com/github/SunRani/IDS/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![HorseFeedGraph.PNG](data:image/png;base64,...)
# ![SumOfWeightTable.PNG](data:image/png;base64,...)

# %% [markdown]
# ![Min_Max_Mean.PNG](data:image/png;base64,...)

# %% [markdown]
# # **Results from Sum of Weight**
# ### From the graph and table, we see that for the sum of all weights for each feed, Sunflower is the highest overall, while Horsebean is the lowest

# %% [markdown]
# # **Min, Mean & Max**
#
# ### Looking at the data here helps us confirm things such as why Linseed is the lowest overall, Linseed's max weight is only 1 higher than Sunflower's lowest. Again, here Sunflower has the overall highest mean weight.

# %% [markdown]
# # **Part 1 Conclusion**
#
#
# ### Based on the data we have seen, Sunflower feed would be the most beneficial as overall it produces the chickens with the higher overall weight.

# %% [markdown]
# ![MeanRatings.PNG](data:image/png;base64,...)![Insurance_Min_Max_Mean.PNG](data:image/png;base64,...)

# %% [markdown]
# # **Results of Insurance Ratings**
# ### From the table and graph we see that overall Progressive has the higher ratings while USAA has the lowest.

# %% [markdown]
# # **Part 2 Conclusion**
#
# ### From the information that was given I would pick Progressive as an insurance comapny. Not just because they have the highest mean rating, but because their lowest rating is a lot higher then the other two.
